# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from evoman.environment import Environment
from controller_custom import player_controller
from multiprocessing import Pool
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd
import warnings
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# # Algorithm A

# %%
def run_algorithm_a(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group, elitism_count=1):
	"""
	Runs Genetic Algorithm A with the provided environment and parameters.

	Parameters:
	- env: Evoman Environment instance.
	- npopulation: Population size.
	- gens: Number of generations.
	- mutation_rate: Mutation rate.
	- dom_u: Upper bound for gene values.
	- dom_l: Lower bound for gene values.
	- elitism_count: Number of elites to preserve.

	Returns:
	- history_mean: List of mean fitness per generation.
	- history_max: List of max fitness per generation.
	- best_solution: Best solution found.
	"""
	
	n_hidden_neurons = 10
	n_vars = (env.get_num_sensors() + 1) * n_hidden_neurons + (n_hidden_neurons + 1) * 5
	
	# Run the simulation and return the fitness
	def simulate(x):
		env.player_controller.set(x, env.get_num_sensors())
		f, _, _, _ = env.play(pcont=x)
		return f
	
	# Evaluate the current population
	def evaluate(population):
		return np.array([simulate(individual) for individual in population])

	# Tournament Selection
	def tournament_selection(population, fitness, k=5):
		selected = []
		for _ in range(len(population)):
			contenders = np.random.choice(len(population), k, replace=False)
			winner = contenders[np.argmax(fitness[contenders])]
			selected.append(population[winner])
		return np.array(selected)

	# Uniform Crossover
	def crossover(parent1, parent2):
		mask = np.random.rand(n_vars) < 0.5
		child1 = np.where(mask, parent1, parent2)
		child2 = np.where(mask, parent2, parent1)
		return child1, child2

	# Gaussian Mutation
	def mutate(child):
		for i in range(n_vars):
			if np.random.rand() < mutation_rate:
				child[i] += np.random.normal(0, 0.1)
				child[i] = np.clip(child[i], dom_l, dom_u)
		return child

	# Initialize population
	population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
	fitness = evaluate(population)

	# Record fitness over generations
	history_mean = []
	history_max = []

	# Genetic Algorithm Loop
	for generation in range(1, gens + 1):
		# Selection
		selected = tournament_selection(population, fitness)

		# Crossover
		offspring = []
		for i in range(0, npopulation, 2):
			parent1, parent2 = selected[i], selected[i+1]
			child1, child2 = crossover(parent1, parent2)
			offspring.extend([child1, child2])
		offspring = np.array(offspring)[:npopulation]

		# Mutation
		offspring = np.array([mutate(child) for child in offspring])

		# Evaluation
		offspring_fitness = evaluate(offspring)

		# Replacement: Elitism (preserve top elitism_count individuals)
		elite_indices = np.argsort(fitness)[-elitism_count:]  
		elite_individuals = population[elite_indices]  
		elite_fitness = fitness[elite_indices]  
		worst_indices = np.argsort(offspring_fitness)[:elitism_count]  
		offspring[worst_indices] = elite_individuals  
		offspring_fitness[worst_indices] = elite_fitness  # Replace the fitness of the worst with elite fitness

		# Update population and fitness
		population, fitness = offspring, offspring_fitness

		# Record statistics
		history_mean.append(np.mean(fitness))
		history_max.append(np.max(fitness))

		# Logging
		print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}')

	# Get best solution
	best_idx = np.argmax(fitness)
	best_solution = population[best_idx]

	np.savetxt(os.path.join('results', f'best_solution_A_{enemy_group}.txt'), best_solution)

	return history_mean, history_max, best_solution

# %% [markdown]
# # Algorithm B

# %%
def run_algorithm_b(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group):
    """
    Runs Genetic Algorithm B with Crowding for preserving diversity.

    Parameters:
    - env: Evoman Environment instance.
    - npopulation: Population size.
    - gens: Number of generations.
    - mutation_rate: Mutation rate.
    - dom_u: Upper bound for gene values.
    - dom_l: Lower bound for gene values.
    - crowding_factor: Factor to determine the number of individuals to compete.

    Returns:
    - history_mean: List of mean fitness per generation.
    - history_max: List of max fitness per generation.
    - best_solution: Best solution found.
    """
    
    n_hidden_neurons = 10
    n_vars = (env.get_num_sensors() + 1) * n_hidden_neurons + (n_hidden_neurons + 1) * 5

    # Run the simulation and return the fitness
    def simulate(x):
        env.player_controller.set(x, env.get_num_sensors())
        f, _, _, _ = env.play(pcont=x)
        return f

    # Evaluate the current population
    def evaluate(population):
        return np.array([simulate(individual) for individual in population])

    # Tournament Selection
    def tournament_selection(population, fitness, k=5):
        selected = []
        for _ in range(len(population)):
            contenders = np.random.choice(len(population), k, replace=False)
            winner = contenders[np.argmax(fitness[contenders])]
            selected.append(population[winner])
        return np.array(selected)

    # Uniform Crossover
    def crossover(parent1, parent2):
        mask = np.random.rand(n_vars) < 0.5
        child1 = np.where(mask, parent1, parent2)
        child2 = np.where(mask, parent2, parent1)
        return child1, child2

    # Gaussian Mutation
    def mutate(child):
        for i in range(n_vars):
            if np.random.rand() < mutation_rate:
                child[i] += np.random.normal(0, 0.1)
                child[i] = np.clip(child[i], dom_l, dom_u)
        return child


    # Initialize population
    population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
    fitness = evaluate(population)

    # Record fitness over generations
    history_mean = []
    history_max = []
    history_std = []

    # Genetic Algorithm Loop
    for generation in range(1, gens + 1):
        # Selection
        selected = tournament_selection(population, fitness)

        # Crossover 
        for i in range(0, npopulation, 2):
            parent1, parent2 = selected[i], selected[i + 1]
            child1, child2 = crossover(parent1, parent2)
            
            # Mutation
            child1 = mutate(child1)
            child2 = mutate(child2)

            # Calculate distances (Euclidean) between parents and offspring
            d_p1_o1 = np.linalg.norm(parent1 - child1)
            d_p1_o2 = np.linalg.norm(parent1 - child2)
            d_p2_o1 = np.linalg.norm(parent2 - child1)
            d_p2_o2 = np.linalg.norm(parent2 - child2)

            # Calculate fitness for offspring
            fitness_child1 = simulate(child1)
            fitness_child2 = simulate(child2)

            # Crowding
            if d_p1_o1 + d_p2_o2 < d_p1_o2 + d_p2_o1:
                # Pair child1 with parent1 and child2 with parent2
                if fitness_child1 > fitness[i]:
                    population[i] = child1
                if fitness_child2 > fitness[i + 1]:
                    population[i + 1] = child2
            else:
                # Pair child1 with parent2 and child2 with parent1
                if fitness_child1 > fitness[i + 1]:
                    population[i + 1] = child1
                if fitness_child2 > fitness[i]:
                    population[i] = child2 

        # Recalculate fitness for the updated population
        fitness = evaluate(population)

        # Record statistics for the generation
        history_mean.append(np.mean(fitness))
        history_max.append(np.max(fitness))
        history_std.append(np.std(fitness))

        # Logging
        print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}, Std = {history_std[-1]:.4f}')

    # Get best solution
    best_idx = np.argmax(fitness)
    best_solution = population[best_idx]

    np.savetxt(os.path.join('results', f'best_solution_B_{enemy_group}.txt'), best_solution)

    return history_mean, history_max, best_solution

# %%
def run_algorithm_b_with_elitism(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group, elitism_count=2):
    """
    Runs Genetic Algorithm B with Crowding and Elitism for preserving diversity and best solutions.
    """
    
    n_hidden_neurons = 10
    n_vars = (env.get_num_sensors() + 1) * n_hidden_neurons + (n_hidden_neurons + 1) * 5

    def simulate(x):
        env.player_controller.set(x, env.get_num_sensors())
        f, _, _, _ = env.play(pcont=x)
        return f

    def evaluate(population):
        return np.array([simulate(individual) for individual in population])

    def tournament_selection(population, fitness, k=5):
        selected = []
        for _ in range(len(population)):
            contenders = np.random.choice(len(population), k, replace=False)
            winner = contenders[np.argmax(fitness[contenders])]
            selected.append(population[winner])
        return np.array(selected)

    def crossover(parent1, parent2):
        mask = np.random.rand(n_vars) < 0.5
        child1 = np.where(mask, parent1, parent2)
        child2 = np.where(mask, parent2, parent1)
        return child1, child2

    def mutate(child):
        for i in range(n_vars):
            if np.random.rand() < mutation_rate:
                child[i] += np.random.normal(0, 0.1)
                child[i] = np.clip(child[i], dom_l, dom_u)
        return child

    def crowding_replace(population, selected, offspring, fitness):
        for i in range(len(selected) // 2):
            parent1, parent2 = selected[2 * i], selected[2 * i + 1]
            child1, child2 = offspring[2 * i], offspring[2 * i + 1]

            d_p1_o1 = np.linalg.norm(parent1 - child1)
            d_p2_o2 = np.linalg.norm(parent2 - child2)
            d_p1_o2 = np.linalg.norm(parent1 - child2)
            d_p2_o1 = np.linalg.norm(parent2 - child1)

            if d_p1_o1 + d_p2_o2 < d_p1_o2 + d_p2_o1:
                if simulate(child1) > simulate(parent1):
                    population[2 * i] = child1
                    fitness[2 * i] = simulate(child1)
                if simulate(child2) > simulate(parent2):
                    population[2 * i + 1] = child2
                    fitness[2 * i + 1] = simulate(child2)
            else:
                if simulate(child1) > simulate(parent2):
                    population[2 * i + 1] = child1
                    fitness[2 * i + 1] = simulate(child1)
                if simulate(child2) > simulate(parent1):
                    population[2 * i] = child2
                    fitness[2 * i] = simulate(child2)

        return population, fitness

    # Elitism Function
    def apply_elitism(population, fitness, num_elites=elitism_count):
        elite_indices = np.argsort(fitness)[-num_elites:]
        elites = population[elite_indices]
        elites_fitness = fitness[elite_indices]
        return elites, elites_fitness

    # Initialize population
    population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
    fitness = evaluate(population)

    history_mean = []
    history_max = []
    history_std = []

    for generation in range(1, gens + 1):
        selected = tournament_selection(population, fitness)

        offspring = []
        for i in range(0, npopulation, 2):
            parent1, parent2 = selected[i], selected[i + 1]
            child1, child2 = crossover(parent1, parent2)
            offspring.extend([child1, child2])
        offspring = np.array(offspring)[:npopulation]

        offspring = np.array([mutate(child) for child in offspring])

        elites, elites_fitness = apply_elitism(population, fitness)
        population, fitness = crowding_replace(population, selected, offspring, fitness)
        population[:elitism_count] = elites
        fitness[:elitism_count] = elites_fitness

        history_mean.append(np.mean(fitness))
        history_max.append(np.max(fitness))
        history_std.append(np.std(fitness))

        print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}, Std = {history_std[-1]:.4f}')

    best_idx = np.argmax(fitness)
    best_solution = population[best_idx]

    np.savetxt(os.path.join('results', f'best_solution_B_{enemy_group}.txt'), best_solution)

    return history_mean, history_max, best_solution

# %% [markdown]
# # Parameters

# %%
# Experiment Parameters

enemy_group_1 = [1, 4, 5, 8]
enemy_group_2 = [2, 3, 6, 7]
enemy_group_3 = [1,2,3,4,5,6,7,8]
num_runs = 10
npopulation = 200
gens = 30 				
mutation_rate = 0.05
dom_u, dom_l = 1, -1
elitism_count_a = 1
elitism_count_b = 2
 

# The number of hidden neurons for the player controller
n_hidden_neurons = 10

# Initialize data storage
results = {
    'Algorithm': [],
    'Enemy Group': [],
    'Run': [],
    'Generation': [],
    'Mean Fitness': [],
    'Max Fitness': [],
    'Best Solution': []
}

best_solutions = {
    'Algorithm': [],
    'Enemy Group': [],
    'Run': [],
    'Best Solution': []
}

# %% [markdown]
# # Run Algorithm A on Enemy Group 1

# %%
print('Running Algorithm A for enemy group 1')

for run in range(1, num_runs +1):
	print(f'Run {run}')
	
	experiment_name = f'EA1_EG1'
	os.makedirs(experiment_name, exist_ok=True)

	env = Environment(experiment_name=experiment_name,
						enemies=enemy_group_1,
						playermode="ai",
						multiplemode="yes",
						player_controller=player_controller(n_hidden_neurons),
						enemymode="static",
						level=2,
						speed="fastest",
						visuals=False)
	
	mean, max, best = run_algorithm_a(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group='enemy_group_1')

	for gen in range(gens):
		results['Algorithm'].append('A')
		results['Enemy Group'].append(1)
		results['Run'].append(run)
		results['Generation'].append(gen)
		results['Mean Fitness'].append(mean[gen])
		results['Max Fitness'].append(max[gen])
		results['Best Solution'].append(best)

	best_solutions['Algorithm'].append('A')
	best_solutions['Enemy Group'].append(1)
	best_solutions['Run'].append(run)
	best_solutions['Best Solution'].append(best)

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join('results', f'results_EA1_EG1.csv'), index=False)
# Out:
# Running Algorithm A for enemy group 1
# Run 1
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 30.1060, Mean Fitness = -3.7939
# Generation 2: Best Fitness = 30.7072, Mean Fitness = -2.6743
# Generation 3: Best Fitness = 30.7072, Mean Fitness = 0.4825
# Generation 4: Best Fitness = 49.9122, Mean Fitness = 4.3151
# Generation 5: Best Fitness = 49.9122, Mean Fitness = 5.2671
# Generation 6: Best Fitness = 54.2883, Mean Fitness = 5.0927
# Generation 7: Best Fitness = 72.8532, Mean Fitness = 7.6859
# Generation 8: Best Fitness = 72.8532, Mean Fitness = 9.1303
# Generation 9: Best Fitness = 72.8532, Mean Fitness = 10.2190
# Generation 10: Best Fitness = 72.8532, Mean Fitness = 10.9567
# Run 2
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 33.1774, Mean Fitness = -4.5856
# Generation 2: Best Fitness = 37.7917, Mean Fitness = -3.2228
# Generation 3: Best Fitness = 42.7931, Mean Fitness = 1.3483
# Generation 4: Best Fitness = 49.8055, Mean Fitness = 3.1507
# Generation 5: Best Fitness = 50.5865, Mean Fitness = 4.7358
# Generation 6: Best Fitness = 50.5865, Mean Fitness = 5.4466
# Generation 7: Best Fitness = 51.8181, Mean Fitness = 7.5478
# Generation 8: Best Fitness = 51.8181, Mean Fitness = 8.3826
# Generation 9: Best Fitness = 51.8181, Mean Fitness = 7.2612
# Generation 10: Best Fitness = 51.8181, Mean Fitness = 7.6836
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Run Algorithm A on Enemy Group 2

# %%
print('Running Algorithm A for enemy group 2')

for run in range(1, num_runs +1):
	print(f'Run {run}')
	
	experiment_name = f'EA1_EG2'
	os.makedirs(experiment_name, exist_ok=True)

	env = Environment(experiment_name=experiment_name,
						enemies=enemy_group_2,
						playermode="ai",
						player_controller=player_controller(n_hidden_neurons),
						enemymode="static",
						level=2,
						speed="fastest",
						visuals=False)
	
	mean, max, best = run_algorithm_a(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group='enemy_group_2')

	for gen in range(gens):
		results['Algorithm'].append('A')
		results['Enemy Group'].append(2)
		results['Run'].append(run)
		results['Generation'].append(gen)
		results['Mean Fitness'].append(mean[gen])
		results['Max Fitness'].append(max[gen])
		results['Best Solution'].append(best)

	best_solutions['Algorithm'].append('A')
	best_solutions['Enemy Group'].append(2)
	best_solutions['Run'].append(run)
	best_solutions['Best Solution'].append(best)

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join('results', f'results_EA1_EG2.csv'), index=False)

# %% [markdown]
# # Run Algorithm B on Enemy Group 1

# %%
print('Running Algorithm B for enemy group 1')

for run in range(1, num_runs +1):
	print(f'Run {run}')
	
	experiment_name = f'EA2_EG1'
	os.makedirs(experiment_name, exist_ok=True)

	env = Environment(experiment_name=experiment_name,
						enemies=enemy_group_1,
						playermode="ai",
						multiplemode="yes",
						player_controller=player_controller(n_hidden_neurons),
						enemymode="static",
						level=2,
						speed="fastest",
						visuals=False)
	
	mean, max, best = run_algorithm_b(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group='enemy_group_1')

	for gen in range(gens):
		results['Algorithm'].append('B')
		results['Enemy Group'].append(1)
		results['Run'].append(run)
		results['Generation'].append(gen)
		results['Mean Fitness'].append(mean[gen])
		results['Max Fitness'].append(max[gen])
		results['Best Solution'].append(best)

	best_solutions['Algorithm'].append('B')
	best_solutions['Enemy Group'].append(1)
	best_solutions['Run'].append(run)
	best_solutions['Best Solution'].append(best)

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join('results', f'results_EA2_EG1.csv'), index=False)
# Out:
# Running Algorithm B for enemy group 1
# Run 1
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 30.4205, Mean Fitness = -2.1405, Std = 7.1852
# Generation 2: Best Fitness = 30.4205, Mean Fitness = 2.4706, Std = 8.8202
# Generation 3: Best Fitness = 54.5532, Mean Fitness = 8.5504, Std = 10.8260
# Generation 4: Best Fitness = 54.5532, Mean Fitness = 12.1882, Std = 11.4531
# Generation 5: Best Fitness = 54.5532, Mean Fitness = 14.2524, Std = 10.9986
# Generation 6: Best Fitness = 54.5532, Mean Fitness = 16.3811, Std = 10.7962
# Generation 7: Best Fitness = 54.5532, Mean Fitness = 18.3991, Std = 10.6394
# Generation 8: Best Fitness = 56.8929, Mean Fitness = 20.8868, Std = 11.2305
# Generation 9: Best Fitness = 56.8929, Mean Fitness = 23.5312, Std = 12.4095
# Generation 10: Best Fitness = 56.8929, Mean Fitness = 25.5719, Std = 12.3482
# Generation 11: Best Fitness = 56.8929, Mean Fitness = 27.3301, Std = 12.6113
# Generation 12: Best Fitness = 56.8929, Mean Fitness = 28.7807, Std = 12.7220
# Generation 13: Best Fitness = 64.1185, Mean Fitness = 30.9036, Std = 13.2002
# Generation 14: Best Fitness = 64.1185, Mean Fitness = 32.5105, Std = 13.1956
# Generation 15: Best Fitness = 64.1185, Mean Fitness = 33.5673, Std = 13.0662
# Generation 16: Best Fitness = 66.6749, Mean Fitness = 35.2118, Std = 12.5568
# Generation 17: Best Fitness = 66.6903, Mean Fitness = 36.9443, Std = 12.5145
# Generation 18: Best Fitness = 66.6903, Mean Fitness = 38.0772, Std = 12.2555
# Generation 19: Best Fitness = 66.6903, Mean Fitness = 39.2343, Std = 11.9815
# Generation 20: Best Fitness = 72.8139, Mean Fitness = 41.6716, Std = 11.8838
# Generation 21: Best Fitness = 72.8139, Mean Fitness = 43.8606, Std = 11.1965
# Generation 22: Best Fitness = 72.8139, Mean Fitness = 45.1125, Std = 10.8232
# Generation 23: Best Fitness = 72.8139, Mean Fitness = 47.0410, Std = 10.4070
# Generation 24: Best Fitness = 72.8139, Mean Fitness = 48.5142, Std = 10.3252
# Generation 25: Best Fitness = 72.8139, Mean Fitness = 49.9266, Std = 9.9994
# Generation 26: Best Fitness = 72.8139, Mean Fitness = 51.7268, Std = 9.7204
# Generation 27: Best Fitness = 72.8139, Mean Fitness = 53.5793, Std = 9.3980
# Generation 28: Best Fitness = 72.8139, Mean Fitness = 55.3252, Std = 8.3623
# Generation 29: Best Fitness = 85.5553, Mean Fitness = 57.4256, Std = 7.9094
# Generation 30: Best Fitness = 85.5553, Mean Fitness = 58.7085, Std = 7.2935
# Run 10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 46.6412, Mean Fitness = -2.8607, Std = 7.3831
# Generation 2: Best Fitness = 46.6412, Mean Fitness = 0.7432, Std = 8.7978
# Generation 3: Best Fitness = 46.6412, Mean Fitness = 5.2418, Std = 10.1234
# Generation 4: Best Fitness = 46.6412, Mean Fitness = 8.4153, Std = 10.5911
# Generation 5: Best Fitness = 56.4394, Mean Fitness = 12.2280, Std = 11.3331
# Generation 6: Best Fitness = 56.4394, Mean Fitness = 15.0521, Std = 11.6287
# Generation 7: Best Fitness = 56.4394, Mean Fitness = 17.1433, Std = 11.9301
# Generation 8: Best Fitness = 56.4394, Mean Fitness = 19.7409, Std = 12.7405
# Generation 9: Best Fitness = 56.4394, Mean Fitness = 22.6240, Std = 14.0333
# Generation 10: Best Fitness = 56.4394, Mean Fitness = 27.7335, Std = 14.7602
# Generation 11: Best Fitness = 66.9204, Mean Fitness = 36.5434, Std = 14.0856
# Generation 12: Best Fitness = 66.9204, Mean Fitness = 43.0174, Std = 11.0552
# Generation 13: Best Fitness = 66.9204, Mean Fitness = 46.5362, Std = 8.9593
# Generation 14: Best Fitness = 66.9204, Mean Fitness = 48.9911, Std = 6.9289
# Generation 15: Best Fitness = 67.0592, Mean Fitness = 50.5143, Std = 6.2549
# Generation 16: Best Fitness = 67.0592, Mean Fitness = 51.5727, Std = 5.3512
# Generation 17: Best Fitness = 71.3654, Mean Fitness = 52.5941, Std = 5.3582
# Generation 18: Best Fitness = 71.3654, Mean Fitness = 53.2950, Std = 5.2568
# Generation 19: Best Fitness = 71.3654, Mean Fitness = 53.6411, Std = 5.1613
# Generation 20: Best Fitness = 71.3654, Mean Fitness = 54.2459, Std = 5.3124
# Generation 21: Best Fitness = 71.3654, Mean Fitness = 54.6483, Std = 5.4104
# Generation 22: Best Fitness = 71.3654, Mean Fitness = 55.0825, Std = 5.3278
# Generation 23: Best Fitness = 71.3654, Mean Fitness = 55.4214, Std = 5.2667
# Generation 24: Best Fitness = 71.3654, Mean Fitness = 55.8269, Std = 5.4099
# Generation 25: Best Fitness = 71.3654, Mean Fitness = 56.3282, Std = 5.5546
# Generation 26: Best Fitness = 71.3654, Mean Fitness = 56.6542, Std = 5.6466
# Generation 27: Best Fitness = 71.3654, Mean Fitness = 56.9218, Std = 5.6216
# Generation 28: Best Fitness = 72.0532, Mean Fitness = 57.2836, Std = 5.7381
# Generation 29: Best Fitness = 72.0532, Mean Fitness = 57.6656, Std = 5.6955
# Generation 30: Best Fitness = 72.0532, Mean Fitness = 57.9227, Std = 5.6232

# %% [markdown]
# # Run Algorithm B on Enemy Group 2

# %%
print('Running Algorithm B for enemy group 2')

for run in range(1, num_runs +1):
	print(f'Run {run}')
	
	experiment_name = f'EA2_EG2'
	os.makedirs(experiment_name, exist_ok=True)

	env = Environment(experiment_name=experiment_name,
						enemies=enemy_group_2,
						multiplemode="yes",
						playermode="ai",
						player_controller=player_controller(n_hidden_neurons),
						enemymode="static",
						level=2,
						speed="fastest",
						visuals=False)
	
	mean, max, best = run_algorithm_b(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group='enemy_group_2')

	for gen in range(gens):
		results['Algorithm'].append('B')
		results['Enemy Group'].append(2)
		results['Run'].append(run)
		results['Generation'].append(gen)
		results['Mean Fitness'].append(mean[gen])
		results['Max Fitness'].append(max[gen])
		results['Best Solution'].append(best)

	best_solutions['Algorithm'].append('B')
	best_solutions['Enemy Group'].append(2)
	best_solutions['Run'].append(run)
	best_solutions['Best Solution'].append(best)

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join('results', f'results_EA2_EG2.csv'), index=False)
# Out:
# Running Algorithm B for enemy group 2
# Run 1
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 33.9398, Mean Fitness = 3.1688, Std = 10.5734
# Generation 2: Best Fitness = 44.5745, Mean Fitness = 11.2462, Std = 11.8523
# Generation 3: Best Fitness = 44.5745, Mean Fitness = 18.5794, Std = 10.2383
# Generation 4: Best Fitness = 44.5745, Mean Fitness = 23.0544, Std = 8.9042
# Generation 5: Best Fitness = 44.5745, Mean Fitness = 25.7799, Std = 8.3325
# Generation 6: Best Fitness = 51.1655, Mean Fitness = 27.3164, Std = 8.6309
# Generation 7: Best Fitness = 56.9917, Mean Fitness = 29.9840, Std = 9.7852
# Generation 8: Best Fitness = 57.0229, Mean Fitness = 35.7106, Std = 11.3821
# Generation 9: Best Fitness = 58.4394, Mean Fitness = 45.3286, Std = 8.3806
# Generation 10: Best Fitness = 62.7117, Mean Fitness = 50.0475, Std = 5.3809
# Generation 11: Best Fitness = 62.7117, Mean Fitness = 51.8852, Std = 4.6859
# Generation 12: Best Fitness = 62.7117, Mean Fitness = 52.8937, Std = 4.3745
# Generation 13: Best Fitness = 62.7117, Mean Fitness = 54.0423, Std = 4.3039
# Generation 14: Best Fitness = 64.2426, Mean Fitness = 54.7173, Std = 4.3111
# Generation 15: Best Fitness = 64.2426, Mean Fitness = 55.3761, Std = 4.1391
# Generation 16: Best Fitness = 64.2426, Mean Fitness = 56.0140, Std = 4.2554
# Generation 17: Best Fitness = 64.2426, Mean Fitness = 56.3857, Std = 4.0067
# Generation 18: Best Fitness = 64.2426, Mean Fitness = 56.9336, Std = 3.9695
# Generation 19: Best Fitness = 64.2426, Mean Fitness = 57.1759, Std = 4.1369
# Generation 20: Best Fitness = 64.2426, Mean Fitness = 57.3769, Std = 4.1924
# Generation 21: Best Fitness = 64.2426, Mean Fitness = 58.0476, Std = 4.0796
# Generation 22: Best Fitness = 64.2426, Mean Fitness = 58.3861, Std = 4.0258
# Generation 23: Best Fitness = 64.2426, Mean Fitness = 58.5512, Std = 4.0210
# Generation 24: Best Fitness = 64.2426, Mean Fitness = 59.1359, Std = 3.8319
# Generation 25: Best Fitness = 64.3983, Mean Fitness = 59.4522, Std = 3.7108
# Run 3
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 35.6721, Mean Fitness = 2.4106, Std = 9.0416
# Generation 2: Best Fitness = 40.8083, Mean Fitness = 11.0119, Std = 11.1770
# Generation 3: Best Fitness = 42.7736, Mean Fitness = 18.6885, Std = 11.6260
# Generation 4: Best Fitness = 42.7736, Mean Fitness = 24.8247, Std = 9.7562
# Generation 5: Best Fitness = 42.7736, Mean Fitness = 28.6666, Std = 6.7804
# Generation 6: Best Fitness = 47.4373, Mean Fitness = 31.9565, Std = 6.2480
# Generation 7: Best Fitness = 54.9596, Mean Fitness = 34.0207, Std = 6.6557
# Generation 8: Best Fitness = 54.9596, Mean Fitness = 35.6137, Std = 6.4991
# Generation 9: Best Fitness = 54.9596, Mean Fitness = 36.9072, Std = 6.8981
# Generation 10: Best Fitness = 61.6488, Mean Fitness = 39.1361, Std = 7.5229
# Generation 11: Best Fitness = 61.9685, Mean Fitness = 40.7010, Std = 7.9169
# Generation 12: Best Fitness = 61.9685, Mean Fitness = 42.3780, Std = 8.4693
# Generation 13: Best Fitness = 61.9685, Mean Fitness = 43.7442, Std = 8.5402
# Generation 14: Best Fitness = 66.1980, Mean Fitness = 45.9345, Std = 9.2891
# Generation 15: Best Fitness = 66.1980, Mean Fitness = 47.5525, Std = 9.3761
# Generation 16: Best Fitness = 69.9633, Mean Fitness = 51.2171, Std = 9.0679
# Generation 17: Best Fitness = 69.9633, Mean Fitness = 53.3103, Std = 8.9660
# Generation 18: Best Fitness = 69.9633, Mean Fitness = 54.0669, Std = 8.7002
# Generation 19: Best Fitness = 69.9633, Mean Fitness = 56.5691, Std = 7.3895
# Generation 20: Best Fitness = 69.9832, Mean Fitness = 57.5973, Std = 7.4678
# Generation 21: Best Fitness = 69.9889, Mean Fitness = 59.5647, Std = 6.8844
# Generation 22: Best Fitness = 69.9889, Mean Fitness = 62.8211, Std = 5.4665
# Generation 23: Best Fitness = 72.5729, Mean Fitness = 64.1262, Std = 4.7692
# Generation 24: Best Fitness = 72.5729, Mean Fitness = 65.2714, Std = 3.4500
# Generation 25: Best Fitness = 72.5729, Mean Fitness = 65.9580, Std = 2.8527
# Generation 26: Best Fitness = 72.5729, Mean Fitness = 66.5854, Std = 2.8727
# Generation 27: Best Fitness = 72.5729, Mean Fitness = 67.4907, Std = 2.4842
# Generation 28: Best Fitness = 72.5729, Mean Fitness = 68.3573, Std = 1.9437
# Generation 29: Best Fitness = 72.6039, Mean Fitness = 68.9915, Std = 1.8010
# Generation 30: Best Fitness = 72.6039, Mean Fitness = 69.3966, Std = 1.5156
# Run 4
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 25.3328, Mean Fitness = 1.2756, Std = 8.3431
# Generation 2: Best Fitness = 41.3044, Mean Fitness = 7.9747, Std = 9.4887
# Generation 3: Best Fitness = 45.1949, Mean Fitness = 13.5953, Std = 10.8562
# Generation 4: Best Fitness = 45.1949, Mean Fitness = 18.2890, Std = 10.9027
