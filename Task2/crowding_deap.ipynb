# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from evoman.environment import Environment
from controller_custom import player_controller
from multiprocessing import Pool
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd
from deap import base, creator, tools, algorithms
import warnings
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# %%
def run_algorithm_b(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group):
    """
    Runs Genetic Algorithm B with Crowding for preserving diversity.

    Parameters:
    - env: Evoman Environment instance.
    - npopulation: Population size.
    - gens: Number of generations.
    - mutation_rate: Mutation rate.
    - dom_u: Upper bound for gene values.
    - dom_l: Lower bound for gene values.
    - crowding_factor: Factor to determine the number of individuals to compete.

    Returns:
    - history_mean: List of mean fitness per generation.
    - history_max: List of max fitness per generation.
    - best_solution: Best solution found.
    """
    
    n_hidden_neurons = 10
    n_vars = (env.get_num_sensors() + 1) * n_hidden_neurons + (n_hidden_neurons + 1) * 5

    # Run the simulation and return the fitness
    def simulate(x):
        env.player_controller.set(x, env.get_num_sensors())
        f, _, _, _ = env.play(pcont=x)
        return f

    # Evaluate the current population
    def evaluate(population):
        return np.array([simulate(individual) for individual in population])

    # Tournament Selection
    def tournament_selection(population, fitness, k=5):
        selected = []
        for _ in range(len(population)):
            contenders = np.random.choice(len(population), k, replace=False)
            winner = contenders[np.argmax(fitness[contenders])]
            selected.append(population[winner])
        return np.array(selected)

    # Uniform Crossover
    def crossover(parent1, parent2):
        mask = np.random.rand(n_vars) < 0.5
        child1 = np.where(mask, parent1, parent2)
        child2 = np.where(mask, parent2, parent1)
        return child1, child2

    # Gaussian Mutation
    def mutate(child):
        for i in range(n_vars):
            if np.random.rand() < mutation_rate:
                child[i] += np.random.normal(0, 0.1)
                child[i] = np.clip(child[i], dom_l, dom_u)
        return child


    # Initialize population
    population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
    fitness = evaluate(population)

    # Record fitness over generations
    history_mean = []
    history_max = []
    history_std = []

    # Genetic Algorithm Loop
    for generation in range(1, gens + 1):
        # Selection
        selected = tournament_selection(population, fitness)

        # Crossover 
        for i in range(0, npopulation-1, 2):
            parent1, parent2 = selected[i], selected[i + 1]
            child1, child2 = crossover(parent1, parent2)
            
            # Mutation
            child1 = mutate(child1)
            child2 = mutate(child2)

            # Calculate distances (Euclidean) between parents and offspring
            d_p1_o1 = np.linalg.norm(parent1 - child1)
            d_p1_o2 = np.linalg.norm(parent1 - child2)
            d_p2_o1 = np.linalg.norm(parent2 - child1)
            d_p2_o2 = np.linalg.norm(parent2 - child2)

            # Calculate fitness for offspring
            fitness_child1 = simulate(child1)
            fitness_child2 = simulate(child2)

            # Crowding
            if d_p1_o1 + d_p2_o2 < d_p1_o2 + d_p2_o1:
                # Pair child1 with parent1 and child2 with parent2
                if fitness_child1 > fitness[i]:
                    population[i] = child1
                if fitness_child2 > fitness[i + 1]:
                    population[i + 1] = child2
            else:
                # Pair child1 with parent2 and child2 with parent1
                if fitness_child1 > fitness[i + 1]:
                    population[i + 1] = child1
                if fitness_child2 > fitness[i]:
                    population[i] = child2 

        # Recalculate fitness for the updated population
        fitness = evaluate(population)

        # Record statistics for the generation
        history_mean.append(np.mean(fitness))
        history_max.append(np.max(fitness))
        history_std.append(np.std(fitness))

        # Logging
        print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}, Std = {history_std[-1]:.4f}')

    # Get best solution
    best_idx = np.argmax(fitness)
    best_solution = population[best_idx]

    np.savetxt(os.path.join('results', f'best_solution_B_{enemy_group}.txt'), best_solution)

    return history_mean, history_max, best_solution

# %% [markdown]
# ## Parameters

# %%
# Experiment Parameters

enemy_group_1 = [1, 4, 5, 8]
enemy_group_2 = [2, 3, 6, 7]
enemy_group_3 = np.arange(1,9)

num_runs = 2 			# Set to 10
npopulation = 200
gens = 10 				# Set to 30
mutation_rate = 0.05
dom_u, dom_l = 1, -1
elitism_count_a = 1
elitism_count_b = 2
 

# The number of hidden neurons for the player controller
n_hidden_neurons = 10

# Initialize data storage
results = {
    'Algorithm': [],
    'Enemy Group': [],
    'Run': [],
    'Generation': [],
    'Mean Fitness': [],
    'Max Fitness': [],
    'Best Solution': []
}

best_solutions = {
    'Algorithm': [],
    'Enemy Group': [],
    'Run': [],
    'Best Solution': []
}

# %% [markdown]
# # Run Algorithm B on Enemy Group 1

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
def objective(params, env, dom_u, dom_l, enemy_group='enemy_group_1'):
    params['npopulation'] = int(params['npopulation'])
    params['gens'] = int(params['gens'])
    
    # Pass dom_u, dom_l, and enemy_group inside params dictionary
    history_mean, history_max, solution = run_algorithm_b(env, **params, dom_u=dom_u, dom_l=dom_l, enemy_group=enemy_group)
    
    return {'loss': -history_max[-1], 'status': STATUS_OK}

def hyperopt_optimization(env, dom_u, dom_l, enemy_group='enemy_group_1', max_evals=5):
    space = {
        'npopulation': hp.quniform('npopulation', 100, 200, 10),
        'gens': hp.quniform('gens', 20, 30, 2),
        'mutation_rate': hp.uniform('mutation_rate', 0.01, 0.1),
    }

    trials = Trials()
    best = fmin(fn=lambda params: objective(params, env, dom_u, dom_l, enemy_group),
                space=space,
                algo=tpe.suggest,
                max_evals=max_evals,
                trials=trials)

    best['npopulation'] = int(best['npopulation'])
    best['gens'] = int(best['gens'])

    return best

# %%
experiment_name = f'optimization_enemy_EG1'
os.makedirs(experiment_name, exist_ok=True)

env = Environment(
    experiment_name=experiment_name,
    multiplemode="yes",
    enemies=enemy_group_1,
    playermode="ai",
    player_controller=player_controller(n_hidden_neurons),
    enemymode="static",
    level=2,
    speed="fastest",
    visuals=False)

best_params = hyperopt_optimization(env, dom_u, dom_l)

print(f"Best parameters for enemy: {best_params}")
print("--------------------")
# Out:
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 32.0387, Mean Fitness = -1.7974, Std = 8.3247
# Generation 2: Best Fitness = 32.0387, Mean Fitness = 2.8440, Std = 9.3303
# Generation 3: Best Fitness = 32.0387, Mean Fitness = 7.1152, Std = 9.8341
# Generation 4: Best Fitness = 35.8827, Mean Fitness = 11.4629, Std = 8.8797
# Generation 5: Best Fitness = 44.9835, Mean Fitness = 15.0048, Std = 9.2741
# Generation 6: Best Fitness = 56.4276, Mean Fitness = 18.4039, Std = 9.7352
# Generation 7: Best Fitness = 56.4276, Mean Fitness = 21.6494, Std = 9.9018
# Generation 8: Best Fitness = 56.4276, Mean Fitness = 24.6525, Std = 9.6180
# Generation 9: Best Fitness = 64.0357, Mean Fitness = 26.9604, Std = 9.8423
# Generation 10: Best Fitness = 64.0357, Mean Fitness = 28.3940, Std = 9.6545
# Generation 11: Best Fitness = 69.6153, Mean Fitness = 30.5642, Std = 10.5051
# Generation 12: Best Fitness = 69.6153, Mean Fitness = 32.3717, Std = 10.5759
# Generation 13: Best Fitness = 69.6153, Mean Fitness = 34.1930, Std = 10.6639
# Generation 14: Best Fitness = 69.6153, Mean Fitness = 35.4237, Std = 10.8099
# Generation 15: Best Fitness = 69.6153, Mean Fitness = 36.8561, Std = 11.2184
# Generation 16: Best Fitness = 69.6153, Mean Fitness = 37.8890, Std = 10.9655
# Generation 17: Best Fitness = 69.6153, Mean Fitness = 39.2437, Std = 10.9362
# Generation 18: Best Fitness = 69.6153, Mean Fitness = 40.5877, Std = 10.9090
# Generation 19: Best Fitness = 69.6306, Mean Fitness = 43.2330, Std = 11.3252
# Generation 20: Best Fitness = 69.6356, Mean Fitness = 44.6018, Std = 11.2516
# Generation 21: Best Fitness = 69.7105, Mean Fitness = 46.7885, Std = 11.6595
# Generation 22: Best Fitness = 69.7105, Mean Fitness = 50.6916, Std = 11.9225
# Generation 23: Best Fitness = 69.7178, Mean Fitness = 54.7012, Std = 11.7668
# Generation 24: Best Fitness = 74.4533, Mean Fitness = 57.9270, Std = 10.6779
# Generation 25: Best Fitness = 74.4533, Mean Fitness = 61.6260, Std = 8.6153
# Generation 26: Best Fitness = 74.4533, Mean Fitness = 63.4318, Std = 7.6483
# Generation 27: Best Fitness = 74.4533, Mean Fitness = 65.0871, Std = 5.5861
# Generation 28: Best Fitness = 74.4533, Mean Fitness = 65.4207, Std = 5.5123
# Generation 29: Best Fitness = 74.4533, Mean Fitness = 66.0590, Std = 4.9734
# Generation 30: Best Fitness = 74.4533, Mean Fitness = 66.5043, Std = 4.6065
# Generation 1: Best Fitness = 37.7592, Mean Fitness = -2.0647, Std = 7.5732
# Generation 2: Best Fitness = 46.6771, Mean Fitness = 2.3217, Std = 9.7093
# Generation 3: Best Fitness = 46.6771, Mean Fitness = 6.7766, Std = 9.8914
# Generation 4: Best Fitness = 46.6771, Mean Fitness = 10.0616, Std = 10.0204
# Generation 5: Best Fitness = 46.6771, Mean Fitness = 13.0449, Std = 10.1991
# Generation 6: Best Fitness = 46.6771, Mean Fitness = 15.3553, Std = 10.3361
# Generation 7: Best Fitness = 46.6771, Mean Fitness = 17.9253, Std = 10.5079
# Generation 8: Best Fitness = 56.3675, Mean Fitness = 21.1858, Std = 11.3761
# Generation 9: Best Fitness = 56.3675, Mean Fitness = 23.2591, Std = 11.1321
# Generation 10: Best Fitness = 56.3675, Mean Fitness = 25.8251, Std = 11.4972
# Generation 11: Best Fitness = 60.6314, Mean Fitness = 28.3369, Std = 11.7415
# Generation 12: Best Fitness = 60.6314, Mean Fitness = 30.2684, Std = 11.9108
# Generation 13: Best Fitness = 63.7457, Mean Fitness = 32.4945, Std = 11.6169
# Generation 14: Best Fitness = 63.7457, Mean Fitness = 35.8510, Std = 11.0850
# Generation 15: Best Fitness = 63.7457, Mean Fitness = 38.0512, Std = 11.1129
# Generation 16: Best Fitness = 63.7457, Mean Fitness = 39.7634, Std = 10.3882
# Generation 17: Best Fitness = 63.7457, Mean Fitness = 42.3988, Std = 9.7063
# Generation 18: Best Fitness = 63.7457, Mean Fitness = 43.4995, Std = 9.0874
# Generation 19: Best Fitness = 66.3471, Mean Fitness = 44.7533, Std = 8.7730
# Generation 20: Best Fitness = 66.3471, Mean Fitness = 45.8365, Std = 8.3012
# Generation 21: Best Fitness = 66.3471, Mean Fitness = 47.0253, Std = 8.0146
# Generation 22: Best Fitness = 66.3471, Mean Fitness = 48.1130, Std = 7.8296
# Generation 23: Best Fitness = 66.3471, Mean Fitness = 48.6243, Std = 7.8133
# Generation 24: Best Fitness = 66.3471, Mean Fitness = 49.4992, Std = 7.8063
# Generation 1: Best Fitness = 21.2642, Mean Fitness = -3.4085, Std = 6.1618
# Generation 2: Best Fitness = 33.8021, Mean Fitness = 1.4375, Std = 9.0013
# Generation 3: Best Fitness = 33.8021, Mean Fitness = 6.2772, Std = 8.6243
# Generation 4: Best Fitness = 38.5676, Mean Fitness = 10.0170, Std = 7.9849
# Generation 5: Best Fitness = 38.5676, Mean Fitness = 12.3481, Std = 7.7005
# Generation 6: Best Fitness = 41.4649, Mean Fitness = 14.7934, Std = 8.4940
# Generation 7: Best Fitness = 52.3450, Mean Fitness = 17.7630, Std = 9.5607
# Generation 8: Best Fitness = 52.4166, Mean Fitness = 20.0274, Std = 10.6709
# Generation 9: Best Fitness = 52.4166, Mean Fitness = 22.5265, Std = 11.4858
# Generation 10: Best Fitness = 58.2027, Mean Fitness = 26.0394, Std = 13.0305
# Generation 11: Best Fitness = 58.2027, Mean Fitness = 28.1543, Std = 13.5058
# Generation 12: Best Fitness = 58.2027, Mean Fitness = 31.7535, Std = 14.5759
# Generation 13: Best Fitness = 58.2027, Mean Fitness = 36.6180, Std = 15.0913
# Generation 14: Best Fitness = 58.2027, Mean Fitness = 43.9874, Std = 12.3222
# Generation 15: Best Fitness = 58.2027, Mean Fitness = 50.0137, Std = 6.1146
# Generation 16: Best Fitness = 58.2027, Mean Fitness = 51.2797, Std = 5.3143
# Generation 17: Best Fitness = 61.0437, Mean Fitness = 51.9286, Std = 4.4840
# Generation 18: Best Fitness = 61.0437, Mean Fitness = 52.5127, Std = 4.1330
# Generation 19: Best Fitness = 61.0437, Mean Fitness = 53.0695, Std = 3.0830
# Generation 20: Best Fitness = 61.1364, Mean Fitness = 53.3461, Std = 3.1339
# Generation 21: Best Fitness = 61.1364, Mean Fitness = 53.8156, Std = 1.8778
# Generation 22: Best Fitness = 61.1364, Mean Fitness = 53.9086, Std = 1.7950
# Generation 23: Best Fitness = 61.1364, Mean Fitness = 54.1416, Std = 1.8789
# Generation 24: Best Fitness = 61.1952, Mean Fitness = 54.2473, Std = 2.0068
# Generation 1: Best Fitness = 34.1498, Mean Fitness = -0.7892, Std = 8.5745
# Generation 2: Best Fitness = 34.1498, Mean Fitness = 3.6378, Std = 10.3932
# Generation 3: Best Fitness = 34.1498, Mean Fitness = 7.7084, Std = 9.8729
# Generation 4: Best Fitness = 34.1498, Mean Fitness = 11.1667, Std = 9.5876
# Generation 5: Best Fitness = 52.3382, Mean Fitness = 14.9731, Std = 9.7989
# Generation 6: Best Fitness = 52.3903, Mean Fitness = 20.4156, Std = 9.9749
# Generation 7: Best Fitness = 52.3903, Mean Fitness = 22.7333, Std = 9.4654
# Generation 8: Best Fitness = 54.5157, Mean Fitness = 25.5747, Std = 10.6180
# Generation 9: Best Fitness = 54.5157, Mean Fitness = 28.6989, Std = 10.4574
# Generation 10: Best Fitness = 54.5157, Mean Fitness = 30.4839, Std = 10.5290
# Generation 11: Best Fitness = 56.3937, Mean Fitness = 32.3784, Std = 10.8567
# Generation 12: Best Fitness = 56.3937, Mean Fitness = 33.0870, Std = 10.6331
# Generation 13: Best Fitness = 56.3937, Mean Fitness = 35.6024, Std = 11.3242
# Generation 14: Best Fitness = 56.3937, Mean Fitness = 38.6092, Std = 11.1725
# Generation 15: Best Fitness = 56.3937, Mean Fitness = 39.6233, Std = 11.4522
# Generation 16: Best Fitness = 56.3937, Mean Fitness = 42.3193, Std = 11.3871
# Generation 17: Best Fitness = 56.3937, Mean Fitness = 45.8829, Std = 10.8784
# Generation 18: Best Fitness = 56.3937, Mean Fitness = 48.9550, Std = 8.9703
# Generation 19: Best Fitness = 56.4256, Mean Fitness = 51.0874, Std = 6.8050
# Generation 20: Best Fitness = 56.4256, Mean Fitness = 52.0510, Std = 6.6441
# Generation 21: Best Fitness = 60.6690, Mean Fitness = 52.9843, Std = 5.5654
# Generation 22: Best Fitness = 63.9557, Mean Fitness = 53.4855, Std = 5.3988
# Generation 23: Best Fitness = 63.9862, Mean Fitness = 54.3052, Std = 5.2511
# Generation 24: Best Fitness = 63.9909, Mean Fitness = 55.9008, Std = 5.8167
# Generation 25: Best Fitness = 63.9909, Mean Fitness = 59.6199, Std = 3.9741
# Generation 26: Best Fitness = 63.9909, Mean Fitness = 62.0583, Std = 2.9761
# Generation 27: Best Fitness = 63.9909, Mean Fitness = 63.0281, Std = 2.0572
# Generation 28: Best Fitness = 64.0138, Mean Fitness = 63.5963, Std = 1.1666
# Generation 29: Best Fitness = 64.0138, Mean Fitness = 63.8310, Std = 0.6687
# Generation 30: Best Fitness = 64.0138, Mean Fitness = 63.8345, Std = 0.6641
# Generation 1: Best Fitness = 55.4654, Mean Fitness = -2.4306, Std = 8.0238
# Generation 2: Best Fitness = 55.4654, Mean Fitness = 1.1489, Std = 9.5293
# Generation 3: Best Fitness = 55.4654, Mean Fitness = 6.3766, Std = 10.9932
# Generation 4: Best Fitness = 55.4654, Mean Fitness = 11.1024, Std = 11.9457
# Generation 5: Best Fitness = 55.4654, Mean Fitness = 13.8619, Std = 12.3136
# Generation 6: Best Fitness = 60.1363, Mean Fitness = 17.3929, Std = 13.5211
# Generation 7: Best Fitness = 60.1363, Mean Fitness = 20.7390, Std = 14.7845
# Generation 8: Best Fitness = 60.1363, Mean Fitness = 23.8236, Std = 16.2095
# Generation 9: Best Fitness = 63.9260, Mean Fitness = 30.8091, Std = 17.2137
# Generation 10: Best Fitness = 64.2385, Mean Fitness = 37.5042, Std = 17.7339
# Generation 11: Best Fitness = 67.4027, Mean Fitness = 50.0742, Std = 14.9959
# Generation 12: Best Fitness = 73.1686, Mean Fitness = 56.7393, Std = 10.0963
# Generation 13: Best Fitness = 73.1686, Mean Fitness = 59.3719, Std = 6.8334
# Generation 14: Best Fitness = 73.1686, Mean Fitness = 61.2470, Std = 3.9588
# Generation 15: Best Fitness = 73.1686, Mean Fitness = 61.9135, Std = 3.6933
# Generation 16: Best Fitness = 73.2124, Mean Fitness = 63.1524, Std = 4.0012
# Generation 17: Best Fitness = 73.2124, Mean Fitness = 63.7672, Std = 4.0418
# Generation 18: Best Fitness = 73.2124, Mean Fitness = 64.2104, Std = 4.0191
# Generation 19: Best Fitness = 73.2124, Mean Fitness = 64.7279, Std = 4.0557
# Generation 20: Best Fitness = 73.3037, Mean Fitness = 65.4002, Std = 4.0092
# Generation 21: Best Fitness = 73.6098, Mean Fitness = 65.9533, Std = 3.9896
# Generation 22: Best Fitness = 73.6098, Mean Fitness = 66.6054, Std = 4.1231
# Generation 23: Best Fitness = 73.6098, Mean Fitness = 66.9096, Std = 4.0004
# Generation 24: Best Fitness = 73.6098, Mean Fitness = 67.3728, Std = 4.1465
# 100%|██████████| 5/5 [52:44<00:00, 632.86s/trial, best loss: -74.45332937937702]
# Best parameters for enemy: {'gens': 30, 'mutation_rate': 0.056367690659474105, 'npopulation': 190}
# --------------------

# %% [markdown]
# ## EA2 on EG1

# %%
print('Running Algorithm B for enemy group 3')

for run in range(1, num_runs +1):
	print(f'Run {run}')
	
	experiment_name = f'EA2_EG1'
	os.makedirs(experiment_name, exist_ok=True)

	env = Environment(experiment_name=experiment_name,
						enemies=enemy_group_1,
						playermode="ai",
						multiplemode="yes",
						player_controller=player_controller(n_hidden_neurons),
						enemymode="static",
						level=2,
						speed="fastest",
						visuals=False)
	
	mean, max, best = run_algorithm_b(env, npopulation, gens, mutation_rate, dom_u, dom_l, enemy_group='enemy_group_1')

	for gen in range(gens):
		results['Algorithm'].append('B')
		results['Enemy Group'].append(1)
		results['Run'].append(run)
		results['Generation'].append(gen)
		results['Mean Fitness'].append(mean[gen])
		results['Max Fitness'].append(max[gen])
		results['Best Solution'].append(best)

	best_solutions['Algorithm'].append('B')
	best_solutions['Enemy Group'].append(1)
	best_solutions['Run'].append(run)
	best_solutions['Best Solution'].append(best)

results_df = pd.DataFrame(results)
results_df.to_csv(os.path.join('results', f'results_EA2_EG1.csv'), index=False)
# Out:
# Running Algorithm B for enemy group 3
# Run 1
#
# MESSAGE: Pygame initialized for simulation.
# Generation 0: Best Fitness = 21.8600, Mean Fitness = -1.2595, Std = 6.5164
# Generation 1: Best Fitness = 24.8009, Mean Fitness = 4.1698, Std = 7.8408
# Generation 2: Best Fitness = 29.6240, Mean Fitness = 9.4904, Std = 7.6730
# Generation 3: Best Fitness = 29.6240, Mean Fitness = 14.2251, Std = 7.1071
# Generation 4: Best Fitness = 31.2466, Mean Fitness = 19.1973, Std = 6.1319
# Generation 5: Best Fitness = 31.2466, Mean Fitness = 21.8275, Std = 5.3545
# Generation 6: Best Fitness = 32.4189, Mean Fitness = 24.9940, Std = 4.7176
# Generation 7: Best Fitness = 32.4189, Mean Fitness = 26.7364, Std = 4.0863
# Generation 8: Best Fitness = 33.9174, Mean Fitness = 28.2226, Std = 2.8616
# Generation 9: Best Fitness = 33.9174, Mean Fitness = 29.0141, Std = 2.1100
# Run 2
#
# MESSAGE: Pygame initialized for simulation.
# Generation 0: Best Fitness = 29.9875, Mean Fitness = 0.6659, Std = 8.4460
# Generation 1: Best Fitness = 49.2106, Mean Fitness = 8.6421, Std = 9.3132
# Generation 2: Best Fitness = 49.2106, Mean Fitness = 15.4661, Std = 7.9487
# Generation 3: Best Fitness = 49.2106, Mean Fitness = 20.2345, Std = 6.0716
# Generation 4: Best Fitness = 50.3780, Mean Fitness = 22.8183, Std = 5.5219
# Generation 5: Best Fitness = 50.3780, Mean Fitness = 24.9959, Std = 4.9925
# Generation 6: Best Fitness = 50.3780, Mean Fitness = 27.5210, Std = 5.1204
# Generation 7: Best Fitness = 50.3780, Mean Fitness = 29.3998, Std = 5.3217
# Generation 8: Best Fitness = 50.3780, Mean Fitness = 31.0590, Std = 5.2575
# Generation 9: Best Fitness = 50.3780, Mean Fitness = 32.3305, Std = 5.2203
