# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from evoman.environment import Environment
from controller1 import player_controller
from evoman.controller import Controller
from multiprocessing import Pool
from scipy.stats import ttest_ind, mannwhitneyu
import pandas as pd
import warnings
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# %%
def run_algorithm_a(env, npopulation=200, gens=30, mutation_rate=0.05, dom_u=1, dom_l=-1):
    """
    Runs Genetic Algorithm A with the provided environment and parameters.

    Parameters:
    - env: Evoman Environment instance.
    - npopulation: Population size.
    - gens: Number of generations.
    - mutation_rate: Mutation rate.
    - dom_u: Upper bound for gene values.
    - dom_l: Lower bound for gene values.
    - elitism_count: Number of elites to preserve.

    Returns:
    - history_mean: List of mean fitness per generation.
    - history_max: List of max fitness per generation.
    - best_solution: Best solution found.
    """
    n_hidden_neurons_1 = 10
    n_hidden_neurons_2 = 5

    n_vars = (
        (env.get_num_sensors() + 1) * n_hidden_neurons_1 +  # Weights and biases from input -> hidden layer 1
        (n_hidden_neurons_1 + 1) * n_hidden_neurons_2 +  # Weights and biases from hidden layer 1 -> hidden layer 2
        (n_hidden_neurons_2 + 1) * 5  # Weights and biases from hidden layer 2 -> output layer (5 actions)
    )

    # Run the simulation and return the fitness
    def simulate(x):
        env.player_controller.set(x, env.get_num_sensors())
        f, _, _, _ = env.play(pcont=x)
        return f

    # Evaluate the current population
    def evaluate(population):
        return np.array([simulate(individual) for individual in population])

    # Tournament Selection
    def tournament_selection(population, fitness, k=5):
        selected = []
        for _ in range(len(population)):
            contenders = np.random.choice(len(population), k, replace=False)
            winner = contenders[np.argmax(fitness[contenders])]
            selected.append(population[winner])
        return np.array(selected)

    # Uniform Crossover
    def crossover(parent1, parent2):
        mask = np.random.rand(n_vars) < 0.5
        child1 = np.where(mask, parent1, parent2)
        child2 = np.where(mask, parent2, parent1)
        return child1, child2

    # Gaussian Mutation
    def mutate(child):
        for i in range(n_vars):
            if np.random.rand() < mutation_rate:
                child[i] += np.random.normal(0, 0.1)
                child[i] = np.clip(child[i], dom_l, dom_u)
        return child

    # Initialize population
    population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
    fitness = evaluate(population)

    # Record fitness over generations
    history_mean = []
    history_max = []

    # Genetic Algorithm Loop
    for generation in range(1, gens + 1):
        # Selection
        selected = tournament_selection(population, fitness)

        # Crossover
        offspring = []
        for i in range(0, npopulation, 2):
            parent1, parent2 = selected[i], selected[i+1]
            child1, child2 = crossover(parent1, parent2)
            offspring.extend([child1, child2])
        offspring = np.array(offspring)[:npopulation]

        # Mutation
        offspring = np.array([mutate(child) for child in offspring])

        # Evaluation
        offspring_fitness = evaluate(offspring)

        # Replacement: Elitism (keep the best individual)
        best_idx = np.argmax(fitness)
        worst_idx = np.argmin(offspring_fitness)
        if fitness[best_idx] > offspring_fitness[worst_idx]:
            offspring[worst_idx] = population[best_idx]
            offspring_fitness[worst_idx] = fitness[best_idx]

        population, fitness = offspring, offspring_fitness

        # Record statistics
        history_mean.append(np.mean(fitness))
        history_max.append(np.max(fitness))

        # Logging
        print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}')

    # Get best solution
    best_idx = np.argmax(fitness)
    best_solution = population[best_idx]

    np.savetxt('best_solution_a.txt', best_solution)

    return history_mean, history_max, best_solution

# %%
def run_algorithm_b(env, npopulation=200, gens=30, mutation_rate=0.05, dom_u=1, dom_l=-1, elitism_count=2, share_alpha=0.1, share_sigma=0.2):
    """
    Runs Genetic Algorithm B (GA with Fitness Sharing for diversity maintenance).

    Parameters:
    - env: Evoman Environment instance.
    - npopulation: Population size.
    - gens: Number of generations.
    - mutation_rate: Mutation rate.
    - dom_u: Upper bound for gene values.
    - dom_l: Lower bound for gene values.
    - elitism_count: Number of elites to preserve.
    - share_alpha: Sharing coefficient.
    - share_sigma: Sharing radius.

    Returns:
    - history_mean: List of mean fitness per generation.
    - history_max: List of max fitness per generation.
    - best_solution: Best solution found.
    """

    n_hidden_neurons_1 = 10
    n_hidden_neurons_2 = 5

    n_vars = (
        (env.get_num_sensors() + 1) * n_hidden_neurons_1 +  # Weights and biases from input -> hidden layer 1
        (n_hidden_neurons_1 + 1) * n_hidden_neurons_2 +  # Weights and biases from hidden layer 1 -> hidden layer 2
        (n_hidden_neurons_2 + 1) * 5  # Weights and biases from hidden layer 2 -> output layer (5 actions)
    )

    # Run the simulation and return the fitness
    def simulate(x):
        # Set the player's controller with the weights 'x'
        env.player_controller.set(x, env.get_num_sensors())
        f, _, _, _ = env.play(pcont=x)
        return f

    # Evaluate the current population
    def evaluate(population):
        return np.array([simulate(individual) for individual in population])

    # Tournament Selection
    def tournament_selection(population, fitness, k=5):
        selected = []
        for _ in range(len(population)):
            contenders = np.random.choice(len(population), k, replace=False)
            winner = contenders[np.argmax(fitness[contenders])]
            selected.append(population[winner])
        return np.array(selected)

    # Two-Point Crossover
    def two_point_crossover(parent1, parent2):
        point1 = np.random.randint(0, n_vars)
        point2 = np.random.randint(point1, n_vars)
        child1 = np.concatenate([parent1[:point1], parent2[point1:point2], parent1[point2:]])
        child2 = np.concatenate([parent2[:point1], parent1[point1:point2], parent2[point2:]])
        return child1, child2

    # Gaussian Mutation
    def mutate(child):
        for i in range(n_vars):
            if np.random.rand() < mutation_rate:
                child[i] += np.random.normal(0, 0.1)
                child[i] = np.clip(child[i], dom_l, dom_u)
        return child

    # Fitness Sharing
    def fitness_sharing(population, fitness, alpha, sigma):
        """
        Adjusts fitness based on similarity using fitness sharing.

        Parameters:
        - population: Current population.
        - fitness: Original fitness values.
        - alpha: Sharing coefficient.
        - sigma: Sharing radius.

        Returns:
        - shared_fitness: Adjusted fitness values.
        """
        shared_fitness = np.copy(fitness)
        npop = population.shape[0]
        for i in range(npop):
            for j in range(npop):
                if i != j:
                    distance = np.linalg.norm(population[i] - population[j])
                    if distance < sigma:
                        shared_fitness[i] -= alpha * (1 - distance / sigma)
        # Ensure that fitness doesn't become negative
        shared_fitness = np.maximum(shared_fitness, 0)
        return shared_fitness

    # Initialize population
    population = np.random.uniform(dom_l, dom_u, (npopulation, n_vars))
    fitness = evaluate(population)

    # Apply Fitness Sharing
    fitness = fitness_sharing(population, fitness, share_alpha, share_sigma)

    # Record fitness over generations
    history_mean = []
    history_max = []

    # Genetic Algorithm Loop
    for generation in range(1, gens + 1):
        # Selection
        selected = tournament_selection(population, fitness)

        # Crossover
        offspring = []
        for i in range(0, npopulation, 2):
            parent1, parent2 = selected[i], selected[i+1]
            child1, child2 = two_point_crossover(parent1, parent2)
            offspring.extend([child1, child2])
        offspring = np.array(offspring)[:npopulation]

        # Mutation
        offspring = np.array([mutate(child) for child in offspring])

        # Evaluation
        offspring_fitness = evaluate(offspring)

        # Apply Fitness Sharing
        offspring_fitness = fitness_sharing(offspring, offspring_fitness, share_alpha, share_sigma)

        # Replacement: Elitism (keep the best individual)
        best_idx = np.argmax(fitness)
        worst_idx = np.argmin(offspring_fitness)
        if fitness[best_idx] > offspring_fitness[worst_idx]:
            offspring[worst_idx] = population[best_idx]
            offspring_fitness[worst_idx] = fitness[best_idx]

        population, fitness = offspring, offspring_fitness

        # Record statistics
        history_mean.append(np.mean(fitness))
        history_max.append(np.max(fitness))

        # Logging
        print(f'Generation {generation}: Best Fitness = {history_max[-1]:.4f}, Mean Fitness = {history_mean[-1]:.4f}')

    # Get best solution
    best_idx = np.argmax(fitness)
    best_solution = population[best_idx]

    np.savetxt(('best_solution_b.txt'), best_solution)

    return history_mean, history_max, best_solution

# %%
# Experiment Parameters
enemy = 6 # singular enemy to test
num_runs = 10 # Change to 10 for full experiment
npopulation = 200
gens = 30 # Change to 30 for full experiment
mutation_rate = 0.05
dom_u, dom_l = 1, -1
elitism_count_a = 1
elitism_count_b = 2
# Define the list of enemies to train against
enemies = [1, 2, 3]  

# The number of hidden neurons for the player controller
n_hidden_neurons_1 = 10
n_hidden_neurons_2 = 5

# Initialize data storage
results = {
    'Algorithm': [],
    'Enemy': [],
    'Run': [],
    'Generation': [],
    'Mean Fitness': [],
    'Max Fitness': [],
    'Best Solution': []
}

best_solutions = {
    'Algorithm': [],
    'Enemy': [],
    'Run': [],
    'Best Solution': []
}

# %% [markdown]
# ### Run this for Algorithm A results

# %%
for enemy in enemies:
    print(f"Training against enemy {enemy}")
        
    for run in range(1, num_runs + 1):
        print(f"Run {run}/{num_runs}")
        
        # Define experiment names for Algorithm A and B
        experiment_name_a = f'optimization_test_a_run_{run}'
        
        # Create directories for Algorithm A and B
        os.makedirs(experiment_name_a, exist_ok=True)
        
        # Initialize Environment for Algorithm A
        env_a = Environment(
            experiment_name=experiment_name_a,
            enemies=[enemy],
            playermode="ai",
            player_controller=player_controller(n_hidden_neurons_1, n_hidden_neurons_2),
            enemymode="ai",
            level=2,
            speed="fastest",
            visuals=False
        )
        
        # Run Algorithm A
        mean_a, max_a, best_a = run_algorithm_a(
            env=env_a,
            npopulation=npopulation,
            gens=gens,
            mutation_rate=mutation_rate,
            dom_u=dom_u,
            dom_l=dom_l
        )
        
        # Record data for Algorithm A
        for gen in range(1, gens + 1):
            results['Algorithm'].append('A')
            results['Enemy'].append(enemy)
            results['Run'].append(run)
            results['Generation'].append(gen)
            results['Mean Fitness'].append(mean_a[gen - 1])
            results['Max Fitness'].append(max_a[gen - 1])
            results['Best Solution'].append(best_a)
        
        best_solutions['Algorithm'].append('A')
        best_solutions['Enemy'].append(enemy)
        best_solutions['Run'].append(run)
        best_solutions['Best Solution'].append(best_a)

# Save results to CSV
results_df = pd.DataFrame(results)
results_df.to_csv('results_a.csv', index=False)

best_solutions_df = pd.DataFrame(best_solutions)
best_solutions_df.to_csv('best_solutions_a.csv', index=False)

# %%
enemy = 3
print(f"Training against enemy {enemy}")
    
for run in range(1, num_runs + 1):
    print(f"Run {run}/{num_runs}")
    
    # Define experiment names for Algorithm A and B
    experiment_name_a = f'optimization_test_a_run_{run}'
    
    # Create directories for Algorithm A and B
    os.makedirs(experiment_name_a, exist_ok=True)
    
    # Initialize Environment for Algorithm A
    env_a = Environment(
        experiment_name=experiment_name_a,
        enemies=[enemy],
        playermode="ai",
        player_controller=player_controller(n_hidden_neurons_1, n_hidden_neurons_2),
        enemymode="ai",
        level=2,
        speed="fastest",
        visuals=False
    )
    
    # Run Algorithm A
    mean_a, max_a, best_a = run_algorithm_a(
        env=env_a,
        npopulation=npopulation,
        gens=gens,
        mutation_rate=mutation_rate,
        dom_u=dom_u,
        dom_l=dom_l
    )
    
    # Record data for Algorithm A
    for gen in range(1, gens + 1):
        results['Algorithm'].append('A')
        results['Enemy'].append(enemy)
        results['Run'].append(run)
        results['Generation'].append(gen)
        results['Mean Fitness'].append(mean_a[gen - 1])
        results['Max Fitness'].append(max_a[gen - 1])
        results['Best Solution'].append(best_a)
    
    best_solutions['Algorithm'].append('A')
    best_solutions['Enemy'].append(enemy)
    best_solutions['Run'].append(run)
    best_solutions['Best Solution'].append(best_a)

# Save results to CSV
results_df = pd.DataFrame(results)
results_df.to_csv('results_a.csv', index=False)

best_solutions_df = pd.DataFrame(best_solutions)
best_solutions_df.to_csv('best_solutions_a.csv', index=False)
# Out:
# Training against enemy 3
# Run 1/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 91.9111, Mean Fitness = 17.6889
# Generation 2: Best Fitness = 94.4512, Mean Fitness = 38.0448
# Generation 3: Best Fitness = 94.4512, Mean Fitness = 47.4492
# Generation 4: Best Fitness = 94.4512, Mean Fitness = 56.3043
# Generation 5: Best Fitness = 94.4512, Mean Fitness = 59.4609
# Generation 6: Best Fitness = 94.4512, Mean Fitness = 65.2539
# Generation 7: Best Fitness = 94.4512, Mean Fitness = 61.8603
# Generation 8: Best Fitness = 94.4512, Mean Fitness = 69.6208
# Generation 9: Best Fitness = 94.4512, Mean Fitness = 64.1755
# Generation 10: Best Fitness = 94.4512, Mean Fitness = 64.0126
# Generation 11: Best Fitness = 94.4512, Mean Fitness = 66.6368
# Generation 12: Best Fitness = 94.4512, Mean Fitness = 67.9481
# Generation 13: Best Fitness = 94.4512, Mean Fitness = 65.6397
# Generation 14: Best Fitness = 94.4512, Mean Fitness = 70.5094
# Generation 15: Best Fitness = 94.4512, Mean Fitness = 68.1048
# Generation 16: Best Fitness = 94.4512, Mean Fitness = 69.4480
# Generation 17: Best Fitness = 94.4512, Mean Fitness = 66.5505
# Generation 18: Best Fitness = 94.4512, Mean Fitness = 71.1300
# Generation 19: Best Fitness = 94.4512, Mean Fitness = 69.1591
# Generation 20: Best Fitness = 94.4512, Mean Fitness = 67.4453
# Generation 21: Best Fitness = 94.4512, Mean Fitness = 72.9288
# Generation 22: Best Fitness = 94.4512, Mean Fitness = 65.3892
# Generation 23: Best Fitness = 94.4512, Mean Fitness = 70.7996
# Generation 24: Best Fitness = 94.4512, Mean Fitness = 70.8237
# Generation 25: Best Fitness = 94.4512, Mean Fitness = 73.3963
# Generation 26: Best Fitness = 94.4512, Mean Fitness = 71.5369
# Generation 27: Best Fitness = 94.6467, Mean Fitness = 70.3376
# Generation 28: Best Fitness = 94.6467, Mean Fitness = 69.9130
# Generation 29: Best Fitness = 94.6467, Mean Fitness = 69.3964
# Generation 30: Best Fitness = 94.6467, Mean Fitness = 71.1626
# Run 2/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.1447, Mean Fitness = 24.3376
# Generation 2: Best Fitness = 92.1447, Mean Fitness = 40.1602
# Generation 3: Best Fitness = 93.4512, Mean Fitness = 53.0423
# Generation 4: Best Fitness = 93.4512, Mean Fitness = 59.3538
# Generation 5: Best Fitness = 93.4512, Mean Fitness = 62.5711
# Generation 6: Best Fitness = 93.4512, Mean Fitness = 64.6110
# Generation 7: Best Fitness = 93.4512, Mean Fitness = 67.3456
# Generation 8: Best Fitness = 93.4512, Mean Fitness = 67.3018
# Generation 9: Best Fitness = 93.4512, Mean Fitness = 69.8285
# Generation 10: Best Fitness = 93.4512, Mean Fitness = 66.8978
# Generation 11: Best Fitness = 93.4512, Mean Fitness = 68.2094
# Generation 12: Best Fitness = 93.4512, Mean Fitness = 68.8724
# Generation 13: Best Fitness = 93.4512, Mean Fitness = 71.9423
# Generation 14: Best Fitness = 93.4512, Mean Fitness = 71.5016
# Generation 15: Best Fitness = 93.4512, Mean Fitness = 73.5258
# Generation 16: Best Fitness = 93.4512, Mean Fitness = 71.0463
# Generation 17: Best Fitness = 93.4512, Mean Fitness = 71.5781
# Generation 18: Best Fitness = 93.4512, Mean Fitness = 70.6359
# Generation 19: Best Fitness = 93.4512, Mean Fitness = 69.1620
# Generation 20: Best Fitness = 93.4512, Mean Fitness = 70.1579
# Generation 21: Best Fitness = 93.4512, Mean Fitness = 68.3393
# Generation 22: Best Fitness = 93.4512, Mean Fitness = 67.9992
# Generation 23: Best Fitness = 93.4512, Mean Fitness = 73.8865
# Generation 24: Best Fitness = 93.4512, Mean Fitness = 72.2881
# Generation 25: Best Fitness = 93.4512, Mean Fitness = 69.4997
# Generation 26: Best Fitness = 93.4512, Mean Fitness = 71.3784
# Generation 27: Best Fitness = 93.4512, Mean Fitness = 67.7832
# Generation 28: Best Fitness = 93.4512, Mean Fitness = 72.4265
# Generation 29: Best Fitness = 93.4512, Mean Fitness = 70.8706
# Generation 30: Best Fitness = 93.4512, Mean Fitness = 70.3542
# Run 3/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 91.9583, Mean Fitness = 23.5321
# Generation 2: Best Fitness = 91.9583, Mean Fitness = 40.0287
# Generation 3: Best Fitness = 93.0117, Mean Fitness = 54.2422
# Generation 4: Best Fitness = 93.0117, Mean Fitness = 57.2900
# Generation 5: Best Fitness = 93.0117, Mean Fitness = 59.9837
# Generation 6: Best Fitness = 93.0117, Mean Fitness = 54.7319
# Generation 7: Best Fitness = 93.0117, Mean Fitness = 59.8570
# Generation 8: Best Fitness = 93.0117, Mean Fitness = 63.3739
# Generation 9: Best Fitness = 93.0117, Mean Fitness = 61.8516
# Generation 10: Best Fitness = 93.0117, Mean Fitness = 62.1131
# Generation 11: Best Fitness = 93.2109, Mean Fitness = 64.4721
# Generation 12: Best Fitness = 93.5168, Mean Fitness = 65.0102
# Generation 13: Best Fitness = 93.5168, Mean Fitness = 65.0767
# Generation 14: Best Fitness = 93.5168, Mean Fitness = 66.0524
# Generation 15: Best Fitness = 93.5168, Mean Fitness = 70.5507
# Generation 16: Best Fitness = 93.5168, Mean Fitness = 70.4438
# Generation 17: Best Fitness = 93.5168, Mean Fitness = 69.0938
# Generation 18: Best Fitness = 93.5168, Mean Fitness = 67.5688
# Generation 19: Best Fitness = 93.5168, Mean Fitness = 69.9202
# Generation 20: Best Fitness = 93.5168, Mean Fitness = 64.7365
# Generation 21: Best Fitness = 93.5168, Mean Fitness = 71.4082
# Generation 22: Best Fitness = 93.5168, Mean Fitness = 68.5260
# Generation 23: Best Fitness = 93.5630, Mean Fitness = 70.1589
# Generation 24: Best Fitness = 93.5630, Mean Fitness = 69.8617
# Generation 25: Best Fitness = 93.5630, Mean Fitness = 67.9877
# Generation 26: Best Fitness = 93.8785, Mean Fitness = 69.4805
# Generation 27: Best Fitness = 93.8785, Mean Fitness = 66.9352
# Generation 28: Best Fitness = 93.8785, Mean Fitness = 71.8197
# Generation 29: Best Fitness = 93.8785, Mean Fitness = 71.3756
# Generation 30: Best Fitness = 93.8785, Mean Fitness = 72.2993
# Run 4/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 91.8868, Mean Fitness = 17.3133
# Generation 2: Best Fitness = 92.6387, Mean Fitness = 37.2738
# Generation 3: Best Fitness = 94.2340, Mean Fitness = 43.6379
# Generation 4: Best Fitness = 94.2340, Mean Fitness = 50.9313
# Generation 5: Best Fitness = 94.2340, Mean Fitness = 58.5782
# Generation 6: Best Fitness = 94.2340, Mean Fitness = 62.5479
# Generation 7: Best Fitness = 94.2340, Mean Fitness = 61.8504
# Generation 8: Best Fitness = 94.2340, Mean Fitness = 65.1016
# Generation 9: Best Fitness = 94.2340, Mean Fitness = 68.4321
# Generation 10: Best Fitness = 94.2340, Mean Fitness = 68.0490
# Generation 11: Best Fitness = 94.2340, Mean Fitness = 65.4388
# Generation 12: Best Fitness = 94.2340, Mean Fitness = 69.2944
# Generation 13: Best Fitness = 94.2340, Mean Fitness = 68.3316
# Generation 14: Best Fitness = 94.2340, Mean Fitness = 64.3102
# Generation 15: Best Fitness = 94.2340, Mean Fitness = 65.1570
# Generation 16: Best Fitness = 94.2340, Mean Fitness = 70.6620
# Generation 17: Best Fitness = 94.2340, Mean Fitness = 70.9194
# Generation 18: Best Fitness = 94.2340, Mean Fitness = 67.9277
# Generation 19: Best Fitness = 94.2340, Mean Fitness = 71.0437
# Generation 20: Best Fitness = 94.2340, Mean Fitness = 68.1492
# Generation 21: Best Fitness = 94.2340, Mean Fitness = 73.8149
# Generation 22: Best Fitness = 94.2340, Mean Fitness = 72.7630
# Generation 23: Best Fitness = 94.2340, Mean Fitness = 67.0318
# Generation 24: Best Fitness = 94.2340, Mean Fitness = 68.1452
# Generation 25: Best Fitness = 94.2340, Mean Fitness = 65.3604
# Generation 26: Best Fitness = 94.2340, Mean Fitness = 67.4075
# Generation 27: Best Fitness = 94.2340, Mean Fitness = 72.0455
# Generation 28: Best Fitness = 94.2340, Mean Fitness = 69.9400
# Generation 29: Best Fitness = 94.2340, Mean Fitness = 69.1794
# Generation 30: Best Fitness = 94.2340, Mean Fitness = 71.9744
# Run 5/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.1152, Mean Fitness = 23.7185
# Generation 2: Best Fitness = 92.1152, Mean Fitness = 44.1729
# Generation 3: Best Fitness = 92.5186, Mean Fitness = 52.6444
# Generation 4: Best Fitness = 92.5186, Mean Fitness = 63.8253
# Generation 5: Best Fitness = 92.5186, Mean Fitness = 63.7575
# Generation 6: Best Fitness = 92.5186, Mean Fitness = 65.6016
# Generation 7: Best Fitness = 93.5761, Mean Fitness = 63.8414
# Generation 8: Best Fitness = 93.7477, Mean Fitness = 63.9155
# Generation 9: Best Fitness = 93.7477, Mean Fitness = 66.3325
# Generation 10: Best Fitness = 93.7477, Mean Fitness = 68.6020
# Generation 11: Best Fitness = 93.7477, Mean Fitness = 71.7491
# Generation 12: Best Fitness = 93.7477, Mean Fitness = 66.2730
# Generation 13: Best Fitness = 93.7477, Mean Fitness = 72.7935
# Generation 14: Best Fitness = 93.7477, Mean Fitness = 71.3752
# Generation 15: Best Fitness = 93.7477, Mean Fitness = 71.0008
# Generation 16: Best Fitness = 93.7477, Mean Fitness = 67.9345
# Generation 17: Best Fitness = 93.7477, Mean Fitness = 73.1072
# Generation 18: Best Fitness = 93.7477, Mean Fitness = 71.3726
# Generation 19: Best Fitness = 93.7477, Mean Fitness = 71.9477
# Generation 20: Best Fitness = 93.7477, Mean Fitness = 71.7383
# Generation 21: Best Fitness = 93.7477, Mean Fitness = 69.5154
# Generation 22: Best Fitness = 93.7477, Mean Fitness = 67.8750
# Generation 23: Best Fitness = 93.7477, Mean Fitness = 69.2224
# Generation 24: Best Fitness = 93.7477, Mean Fitness = 70.8390
# Generation 25: Best Fitness = 93.7477, Mean Fitness = 70.6351
# Generation 26: Best Fitness = 93.7477, Mean Fitness = 74.2149
# Generation 27: Best Fitness = 93.7477, Mean Fitness = 70.3895
# Generation 28: Best Fitness = 93.7477, Mean Fitness = 69.1549
# Generation 29: Best Fitness = 93.7477, Mean Fitness = 71.9865
# Generation 30: Best Fitness = 93.7477, Mean Fitness = 70.9794
# Run 6/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.2247, Mean Fitness = 18.0438
# Generation 2: Best Fitness = 93.7576, Mean Fitness = 42.1307
# Generation 3: Best Fitness = 93.7576, Mean Fitness = 49.3546
# Generation 4: Best Fitness = 93.7576, Mean Fitness = 53.0816
# Generation 5: Best Fitness = 93.7576, Mean Fitness = 62.1720
# Generation 6: Best Fitness = 93.7576, Mean Fitness = 63.9696
# Generation 7: Best Fitness = 93.7576, Mean Fitness = 65.5210
# Generation 8: Best Fitness = 93.7576, Mean Fitness = 68.2153
# Generation 9: Best Fitness = 93.7576, Mean Fitness = 67.5157
# Generation 10: Best Fitness = 93.7576, Mean Fitness = 68.6922
# Generation 11: Best Fitness = 93.7576, Mean Fitness = 67.2843
# Generation 12: Best Fitness = 93.7576, Mean Fitness = 67.9724
# Generation 13: Best Fitness = 93.7576, Mean Fitness = 65.3855
# Generation 14: Best Fitness = 93.7576, Mean Fitness = 69.9642
# Generation 15: Best Fitness = 93.7576, Mean Fitness = 68.7676
# Generation 16: Best Fitness = 93.7576, Mean Fitness = 66.7493
# Generation 17: Best Fitness = 93.7576, Mean Fitness = 70.7545
# Generation 18: Best Fitness = 93.7576, Mean Fitness = 68.7447
# Generation 19: Best Fitness = 93.7576, Mean Fitness = 68.1860
# Generation 20: Best Fitness = 93.7576, Mean Fitness = 71.0326
# Generation 21: Best Fitness = 93.7576, Mean Fitness = 74.6372
# Generation 22: Best Fitness = 93.7576, Mean Fitness = 70.4209
# Generation 23: Best Fitness = 93.7576, Mean Fitness = 69.5214
# Generation 24: Best Fitness = 93.7576, Mean Fitness = 69.4456
# Generation 25: Best Fitness = 93.7576, Mean Fitness = 69.4465
# Generation 26: Best Fitness = 93.7576, Mean Fitness = 74.9912
# Generation 27: Best Fitness = 93.7576, Mean Fitness = 71.2215
# Generation 28: Best Fitness = 93.7576, Mean Fitness = 72.2903
# Generation 29: Best Fitness = 93.7576, Mean Fitness = 73.0738
# Generation 30: Best Fitness = 93.7576, Mean Fitness = 71.2751
# Run 7/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.4838, Mean Fitness = 22.1283
# Generation 2: Best Fitness = 92.4838, Mean Fitness = 43.3530
# Generation 3: Best Fitness = 92.4838, Mean Fitness = 51.0152
# Generation 4: Best Fitness = 93.1663, Mean Fitness = 59.1701
# Generation 5: Best Fitness = 93.1663, Mean Fitness = 61.7101
# Generation 6: Best Fitness = 93.3696, Mean Fitness = 57.4445
# Generation 7: Best Fitness = 93.3696, Mean Fitness = 65.8425
# Generation 8: Best Fitness = 93.3696, Mean Fitness = 61.4203
# Generation 9: Best Fitness = 93.3696, Mean Fitness = 63.3827
# Generation 10: Best Fitness = 93.3696, Mean Fitness = 67.6411
# Generation 11: Best Fitness = 93.3696, Mean Fitness = 69.9643
# Generation 12: Best Fitness = 93.3696, Mean Fitness = 69.5830
# Generation 13: Best Fitness = 93.3696, Mean Fitness = 67.1242
# Generation 14: Best Fitness = 93.4745, Mean Fitness = 69.0712
# Generation 15: Best Fitness = 93.4745, Mean Fitness = 69.7997
# Generation 16: Best Fitness = 93.8109, Mean Fitness = 69.4455
# Generation 17: Best Fitness = 93.8109, Mean Fitness = 71.1797
# Generation 18: Best Fitness = 93.8294, Mean Fitness = 67.4463
# Generation 19: Best Fitness = 93.8294, Mean Fitness = 70.7936
# Generation 20: Best Fitness = 94.0126, Mean Fitness = 71.7787
# Generation 21: Best Fitness = 94.0126, Mean Fitness = 68.5647
# Generation 22: Best Fitness = 94.0126, Mean Fitness = 69.4932
# Generation 23: Best Fitness = 94.0126, Mean Fitness = 69.8334
# Generation 24: Best Fitness = 94.0126, Mean Fitness = 72.9192
# Generation 25: Best Fitness = 94.0126, Mean Fitness = 74.2568
# Generation 26: Best Fitness = 94.0126, Mean Fitness = 74.5001
# Generation 27: Best Fitness = 94.0126, Mean Fitness = 69.3386
# Generation 28: Best Fitness = 94.0126, Mean Fitness = 69.7650
# Generation 29: Best Fitness = 94.0126, Mean Fitness = 70.1763
# Generation 30: Best Fitness = 94.0126, Mean Fitness = 72.3320
# Run 8/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 91.7533, Mean Fitness = 24.0028
# Generation 2: Best Fitness = 92.2348, Mean Fitness = 41.3666
# Generation 3: Best Fitness = 92.5724, Mean Fitness = 50.3483
# Generation 4: Best Fitness = 92.5724, Mean Fitness = 59.4148
# Generation 5: Best Fitness = 92.5724, Mean Fitness = 61.2112
# Generation 6: Best Fitness = 92.5724, Mean Fitness = 63.4919
# Generation 7: Best Fitness = 92.5724, Mean Fitness = 60.2488
# Generation 8: Best Fitness = 92.5724, Mean Fitness = 60.3900
# Generation 9: Best Fitness = 92.5724, Mean Fitness = 66.6919
# Generation 10: Best Fitness = 92.5724, Mean Fitness = 67.3419
# Generation 11: Best Fitness = 92.6929, Mean Fitness = 66.7946
# Generation 12: Best Fitness = 92.6929, Mean Fitness = 70.7936
# Generation 13: Best Fitness = 92.6929, Mean Fitness = 71.4526
# Generation 14: Best Fitness = 92.6929, Mean Fitness = 69.7311
# Generation 15: Best Fitness = 92.6929, Mean Fitness = 70.0664
# Generation 16: Best Fitness = 92.6929, Mean Fitness = 69.6760
# Generation 17: Best Fitness = 93.6155, Mean Fitness = 69.7461
# Generation 18: Best Fitness = 93.6155, Mean Fitness = 72.3467
# Generation 19: Best Fitness = 94.6294, Mean Fitness = 70.9871
# Generation 20: Best Fitness = 94.6294, Mean Fitness = 71.6644
# Generation 21: Best Fitness = 94.6294, Mean Fitness = 70.2036
# Generation 22: Best Fitness = 94.6294, Mean Fitness = 69.8325
# Generation 23: Best Fitness = 94.6294, Mean Fitness = 69.4751
# Generation 24: Best Fitness = 94.6294, Mean Fitness = 69.9982
# Generation 25: Best Fitness = 94.6294, Mean Fitness = 72.3936
# Generation 26: Best Fitness = 94.6294, Mean Fitness = 70.4900
# Generation 27: Best Fitness = 94.6294, Mean Fitness = 70.7851
# Generation 28: Best Fitness = 94.6294, Mean Fitness = 69.4970
# Generation 29: Best Fitness = 94.6294, Mean Fitness = 71.5330
# Generation 30: Best Fitness = 94.6294, Mean Fitness = 70.4500
# Run 9/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.1576, Mean Fitness = 31.9898
# Generation 2: Best Fitness = 92.4317, Mean Fitness = 50.9362
# Generation 3: Best Fitness = 92.7750, Mean Fitness = 55.4739
# Generation 4: Best Fitness = 92.7750, Mean Fitness = 59.7287
# Generation 5: Best Fitness = 92.7750, Mean Fitness = 62.6027
# Generation 6: Best Fitness = 92.8666, Mean Fitness = 61.2705
# Generation 7: Best Fitness = 92.8666, Mean Fitness = 60.2916
# Generation 8: Best Fitness = 92.8666, Mean Fitness = 66.9601
# Generation 9: Best Fitness = 92.8666, Mean Fitness = 68.8801
# Generation 10: Best Fitness = 92.8666, Mean Fitness = 70.7318
# Generation 11: Best Fitness = 92.8666, Mean Fitness = 68.4569
# Generation 12: Best Fitness = 92.8666, Mean Fitness = 69.2775
# Generation 13: Best Fitness = 92.8666, Mean Fitness = 68.3619
# Generation 14: Best Fitness = 92.8666, Mean Fitness = 71.0653
# Generation 15: Best Fitness = 93.3566, Mean Fitness = 67.3934
# Generation 16: Best Fitness = 93.3566, Mean Fitness = 68.6379
# Generation 17: Best Fitness = 93.4873, Mean Fitness = 70.1389
# Generation 18: Best Fitness = 93.4873, Mean Fitness = 68.9950
# Generation 19: Best Fitness = 93.4873, Mean Fitness = 70.2842
# Generation 20: Best Fitness = 93.4873, Mean Fitness = 69.6105
# Generation 21: Best Fitness = 93.5696, Mean Fitness = 70.1498
# Generation 22: Best Fitness = 93.5696, Mean Fitness = 70.0744
# Generation 23: Best Fitness = 93.5696, Mean Fitness = 71.2303
# Generation 24: Best Fitness = 93.5696, Mean Fitness = 72.9056
# Generation 25: Best Fitness = 93.5696, Mean Fitness = 72.3761
# Generation 26: Best Fitness = 93.5696, Mean Fitness = 69.7365
# Generation 27: Best Fitness = 93.5696, Mean Fitness = 72.7863
# Generation 28: Best Fitness = 93.5696, Mean Fitness = 70.5497
# Generation 29: Best Fitness = 93.5696, Mean Fitness = 72.1757
# Generation 30: Best Fitness = 93.5696, Mean Fitness = 70.7929
# Run 10/10
#
# MESSAGE: Pygame initialized for simulation.
# Generation 1: Best Fitness = 92.5336, Mean Fitness = 23.3354
# Generation 2: Best Fitness = 93.3362, Mean Fitness = 39.7878
# Generation 3: Best Fitness = 93.3696, Mean Fitness = 58.9190
# Generation 4: Best Fitness = 93.3696, Mean Fitness = 59.2448
# Generation 5: Best Fitness = 93.3696, Mean Fitness = 58.7791
# Generation 6: Best Fitness = 93.3696, Mean Fitness = 63.1302
# Generation 7: Best Fitness = 93.3696, Mean Fitness = 63.0909
# Generation 8: Best Fitness = 93.3696, Mean Fitness = 66.9558
# Generation 9: Best Fitness = 93.3696, Mean Fitness = 62.7202
# Generation 10: Best Fitness = 93.3696, Mean Fitness = 64.6823
# Generation 11: Best Fitness = 93.3696, Mean Fitness = 65.6407
# Generation 12: Best Fitness = 93.3696, Mean Fitness = 64.1751
# Generation 13: Best Fitness = 93.3696, Mean Fitness = 72.3504
# Generation 14: Best Fitness = 93.3696, Mean Fitness = 65.6535
# Generation 15: Best Fitness = 93.6085, Mean Fitness = 67.6756
# Generation 16: Best Fitness = 93.6085, Mean Fitness = 69.6296
# Generation 17: Best Fitness = 93.6085, Mean Fitness = 66.3992
# Generation 18: Best Fitness = 93.6085, Mean Fitness = 69.4551
# Generation 19: Best Fitness = 93.6085, Mean Fitness = 65.6154
# Generation 20: Best Fitness = 93.6085, Mean Fitness = 67.1185
# Generation 21: Best Fitness = 93.6085, Mean Fitness = 66.9801
# Generation 22: Best Fitness = 93.6085, Mean Fitness = 69.8150
# Generation 23: Best Fitness = 93.6085, Mean Fitness = 68.6660
# Generation 24: Best Fitness = 93.6085, Mean Fitness = 68.7811
# Generation 25: Best Fitness = 93.6085, Mean Fitness = 66.1396
# Generation 26: Best Fitness = 93.6085, Mean Fitness = 70.8425
# Generation 27: Best Fitness = 93.6085, Mean Fitness = 70.9789
# Generation 28: Best Fitness = 93.6085, Mean Fitness = 69.9250
# Generation 29: Best Fitness = 93.6085, Mean Fitness = 71.3476
# Generation 30: Best Fitness = 93.6085, Mean Fitness = 66.2547

# %% [markdown]
# ### Run this for Algorithm B

# %%
for enemy in enemies:
    print(f"Training against enemy {enemy}")
        
    for run in range(1, num_runs + 1):
        print(f"Run {run}/{num_runs}")
        
        # Initialize Environment for Algorithm B
        env_b = Environment(
            experiment_name=experiment_name_b,
            enemies=[enemy],
            playermode="ai",
            player_controller=player_controller(n_hidden_neurons_1, n_hidden_neurons_2),
            enemymode="ai",
            level=2,
            speed="fastest",
            visuals=False
        )
        
        # Run Algorithm B
        mean_b, max_b, best_b = run_algorithm_b(
            env=env_b,
            npopulation=npopulation,
            gens=gens,
            mutation_rate=mutation_rate,
            dom_u=dom_u,
            dom_l=dom_l,
            elitism_count=elitism_count_b
        )
        
        # Record data for Algorithm B
        for gen in range(1, gens + 1):
            results['Algorithm'].append('B')
            results['Enemy'].append(enemy)
            results['Run'].append(run)
            results['Generation'].append(gen)
            results['Mean Fitness'].append(mean_b[gen - 1])
            results['Max Fitness'].append(max_b[gen - 1])
            results['Best Solution'].append(best_b)
        
        best_solutions['Algorithm'].append('B')
        best_solutions['Enemy'].append(enemy)
        best_solutions['Run'].append(run)
        best_solutions['Best Solution'].append(best_b)

# Save results to CSV
results_df = pd.DataFrame(results)
results_df.to_csv('results_b.csv', index=False)

best_solutions_df = pd.DataFrame(best_solutions)
best_solutions_df.to_csv('best_solutions_b.csv', index=False)
